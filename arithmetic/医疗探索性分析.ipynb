# %% [markdown]
# # 数据分析流程
# 1. 获取原始数据
# 2. 数据预处理（清洗和特征工程）

# %%
import pandas as pd

# %%
data = pd.read_csv('2.csv',engine='python')
data
# Out:
#                                                Authors  \
# 0    Klionsky D.J., Abdalla F.C., Abeliovich H., Ab...
# 1    Li-Yu J., Clayburne G., Sieck M., Beutler A., ...
# 2    Stadelmann C., Ludwin S., Tabira T., Guseo A.,...
# 3    Tesser A., Crepaz N., Collins J.C., Cornell D....
# 4    Zucca F.A., Segura-Aguilar J., Ferrari E., Muñ...
# ..                                                 ...
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
#
#                                           Author(s) ID  \
# 0    7004321762;7004339513;55936658000;56776945400;...
# 1    56131193900;6603516749;7004821525;7004035991;7...
# 2    6603989032;7003683815;7102372471;6701819366;35...
# 3    7003885334;6701696846;55461320400;7005706535;3...
# 4    6603173218;7004239555;7202281516;56425262800;1...
# ..                                                 ...
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
#
#                                                  Title    Year  \
# 0    Guidelines for the use and interpretation of a...  2012.0
# 1    Treatment of chronic gout. Can we determine wh...  2001.0
# 2    Tissue preconditioning may explain concentric ...  2005.0
# 3    Confluence of self-esteem regulation mechanism...  2000.0
# 4    Interactions of iron, dopamine and neuromelani...  2017.0
# ..                                                 ...     ...
# 141                                                NaN     NaN
# 142                                                NaN     NaN
# 143                                                NaN     NaN
# 144                                                NaN     NaN
# 145                                                NaN     NaN
#
#                                    Source title  Volume Issue Art. No.  \
# 0                                     Autophagy     8.0     4      NaN
# 1                       Journal of Rheumatology    28.0     3      NaN
# 2                                         Brain   128.0     5      NaN
# 3    Personality and Social Psychology Bulletin    26.0    12      NaN
# 4                      Progress in Neurobiology   155.0   NaN      NaN
# ..                                          ...     ...   ...      ...
# 141                                         NaN     NaN   NaN      NaN
# 142                                         NaN     NaN   NaN      NaN
# 143                                         NaN     NaN   NaN      NaN
# 144                                         NaN     NaN   NaN      NaN
# 145                                         NaN     NaN   NaN      NaN
#
#      Page start  Page end  ...  ISBN  CODEN   PubMed ID  \
# 0         445.0     544.0  ...   NaN    NaN  22966490.0
# 1         577.0     580.0  ...   NaN  JRHUA  11296962.0
# 2         979.0     987.0  ...   NaN  BRAIA  15774507.0
# 3        1476.0    1489.0  ...   NaN    NaN         NaN
# 4          96.0     119.0  ...   NaN  PGNBA  26455458.0
# ..          ...       ...  ...   ...    ...         ...
# 141         NaN       NaN  ...   NaN    NaN         NaN
# 142         NaN       NaN  ...   NaN    NaN         NaN
# 143         NaN       NaN  ...   NaN    NaN         NaN
# 144         NaN       NaN  ...   NaN    NaN         NaN
# 145         NaN       NaN  ...   NaN    NaN         NaN
#
#     Language of Original Document   Abbreviated Source Title Document Type  \
# 0                         English                  Autophagy        Review
# 1                         English              J. Rheumatol.       Article
# 2                         English                      Brain       Article
# 3                         English  Pers. Soc. Psychol. Bull.       Article
# 4                         English           Prog. Neurobiol.        Review
# ..                            ...                        ...           ...
# 141                           NaN                        NaN           NaN
# 142                           NaN                        NaN           NaN
# 143                           NaN                        NaN           NaN
# 144                           NaN                        NaN           NaN
# 145                           NaN                        NaN           NaN
#
#     Publication Stage  Access Type  Source                 EID
# 0               Final  Open Access  Scopus  2-s2.0-84862295360
# 1               Final          NaN  Scopus   2-s2.0-0035093686
# 2               Final  Open Access  Scopus  2-s2.0-18744394057
# 3               Final          NaN  Scopus   2-s2.0-0034360761
# 4               Final          NaN  Scopus  2-s2.0-84952845727
# ..                ...          ...     ...                 ...
# 141               NaN          NaN     NaN                 NaN
# 142               NaN          NaN     NaN                 NaN
# 143               NaN          NaN     NaN                 NaN
# 144               NaN          NaN     NaN                 NaN
# 145               NaN          NaN     NaN                 NaN
#
# [146 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Authors                        60 non-null     object
#  1   Author(s) ID                   60 non-null     object
#  2   Title                          60 non-null     object
#  3   Year                           60 non-null     float64
#  4   Source title                   60 non-null     object
#  5   Volume                         59 non-null     float64
#  6   Issue                          53 non-null     object
#  7   Art. No.                       10 non-null     object
#  8   Page start                     51 non-null     float64
#  9   Page end                       51 non-null     float64
#  10  Page count                     0 non-null      float64
#  11  Cited by                       60 non-null     float64
#  12  DOI                            56 non-null     object
#  13  Link                           60 non-null     object
#  14  Affiliations                   60 non-null     object
#  15  Authors with affiliations      60 non-null     object
#  16  Abstract                       60 non-null     object
#  17  Author Keywords                46 non-null     object
#  18  Index Keywords                 50 non-null     object
#  19  Correspondence Address         57 non-null     object
#  20  Editors                        0 non-null      float64
#  21  Publisher                      37 non-null     object
#  22  ISSN                           60 non-null     object
#  23  ISBN                           0 non-null      float64
#  24  CODEN                          34 non-null     object
#  25  PubMed ID                      33 non-null     float64
#  26  Language of Original Document  60 non-null     object
#  27  Abbreviated Source Title       60 non-null     object
#  28  Document Type                  60 non-null     object
#  29  Publication Stage              60 non-null     object
#  30  Access Type                    19 non-null     object
#  31  Source                         60 non-null     object
#  32  EID                            60 non-null     object
# dtypes: float64(9), object(24)
# memory usage: 37.8+ KB

# %% [markdown]
# 以矩阵形式展示数据

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 数据预处理

# %%
# 根据刚才的图可以大概知道有横线的地方缺失值较严重，对应到具体列
# out_f.列.isnull()   查找该列具体是哪几行为缺失

# %%
(data.isnull()).sum()
# Out:
# Authors                           86
# Author(s) ID                      86
# Title                             86
# Year                              86
# Source title                      86
# Volume                            87
# Issue                             93
# Art. No.                         136
# Page start                        95
# Page end                          95
# Page count                       146
# Cited by                          86
# DOI                               90
# Link                              86
# Affiliations                      86
# Authors with affiliations         86
# Abstract                          86
# Author Keywords                  100
# Index Keywords                    96
# Correspondence Address            89
# Editors                          146
# Publisher                        109
# ISSN                              86
# ISBN                             146
# CODEN                            112
# PubMed ID                        113
# Language of Original Document     86
# Abbreviated Source Title          86
# Document Type                     86
# Publication Stage                 86
# Access Type                      127
# Source                            86
# EID                               86
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  #用来正常显示负号


fig = plt.figure(figsize=(12,8))    #12:8的长宽比新建画布
